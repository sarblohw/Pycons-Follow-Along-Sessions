# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import dtale
import sweetviz as sv
from pandas_profiling import ProfileReport

# %matplotlib inline
pd.options.display.max_columns = 100

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
extract = df.loc[:, ['Respondent', 'LanguageWorkedWith']]

# %%
extract.head(3)
# Out:
#    Respondent               LanguageWorkedWith
# 0           1  HTML/CSS;Java;JavaScript;Python
# 1           2              C++;HTML/CSS;Python
# 2           3                         HTML/CSS

# %%
extract.to_csv('extract.csv')

# %%
df.head(3)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
#
#           Student                                            EdLevel  \
# ...

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://noor:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
x = df['Age']
y = df['ConvertedComp']

# %%
plt.style.use('bmh')
plt.figure(figsize=[8,4])
plt.bar(x, y, label='Compensation in USD')
plt.xlabel('Age')
plt.ylabel('Compensation USD')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.title('Compensation by Age')
plt.show()
# Out:
# <ipython-input-17-5e32457d57e8>:8: UserWarning:
#
# Creating legend with loc="best" can be slow with large amounts of data.
#
# /home/noor/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning:
#
# Creating legend with loc="best" can be slow with large amounts of data.
# Executing shutdown due to inactivity...
# 2021-06-15 21:54:49,276 - INFO     - Executing shutdown due to inactivity...
# Executing shutdown...
# 2021-06-15 21:54:49,294 - INFO     - Executing shutdown...

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
import csv

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(), cmap='YlGnBu', annot=True)
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# Respondent       1.000000  -0.003357       0.002930    -0.004589   -0.005240
# CompTotal       -0.003357   1.000000       0.039725     0.003074    0.061090
# ConvertedComp    0.002930   0.039725       1.000000     0.013908   -0.021261
# WorkWeekHrs     -0.004589   0.003074       0.013908     1.000000    0.021092
# CodeRevHrs      -0.005240   0.061090      -0.021261     0.021092    1.000000
# Age             -0.001829   0.016500       0.108268     0.019976   -0.022486
#
#                     Age
# Respondent    -0.001829
# CompTotal      0.016500
# ConvertedComp  0.108268
# WorkWeekHrs    0.019976
# CodeRevHrs    -0.022486
# Age            1.000000

# %%
df_cumulative = pd.read_csv('cumulative.csv')

# %%
sns.heatmap(df_cumulative.corr())
# Out:
# <AxesSubplot:>
