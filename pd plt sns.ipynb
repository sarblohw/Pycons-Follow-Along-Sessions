# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
for i, row in iris.iterrows():
    print(i, row['sepal_length'])
# Out:
# 0 5.1
# 1 4.9
# 2 4.7
# 3 4.6
# 4 5.0
# 5 5.4
# 6 4.6
# 7 5.0
# 8 4.4
# 9 4.9
# 10 5.4
# 11 4.8
# 12 4.8
# 13 4.3
# 14 5.8
# 15 5.7
# 16 5.4
# 17 5.1
# 18 5.7
# 19 5.1
# 20 5.4
# 21 5.1
# 22 4.6
# 23 5.1
# 24 4.8
# 25 5.0
# 26 5.0
# 27 5.2
# 28 5.2
# 29 4.7
# 30 4.8
# 31 5.4
# 32 5.2
# 33 5.5
# 34 4.9
# 35 5.0
# 36 5.5
# 37 4.9
# 38 4.4
# 39 5.1
# 40 5.0
# 41 4.5
# 42 4.4
# 43 5.0
# 44 5.1
# 45 4.8
# 46 5.1
# 47 4.6
# 48 5.3
# 49 5.0
# 50 7.0
# 51 6.4
# 52 6.9
# 53 5.5
# 54 6.5
# 55 5.7
# 56 6.3
# 57 4.9
# 58 6.6
# 59 5.2
# 60 5.0
# 61 5.9
# 62 6.0
# 63 6.1
# 64 5.6
# 65 6.7
# 66 5.6
# 67 5.8
# 68 6.2
# 69 5.6
# 70 5.9
# 71 6.1
# 72 6.3
# 73 6.1
# 74 6.4
# 75 6.6
# 76 6.8
# 77 6.7
# 78 6.0
# 79 5.7
# 80 5.5
# 81 5.5
# 82 5.8
# 83 6.0
# 84 5.4
# 85 6.0
# 86 6.7
# 87 6.3
# 88 5.6
# 89 5.5
# 90 5.5
# 91 6.1
# 92 5.8
# 93 5.0
# 94 5.6
# 95 5.7
# 96 5.7
# 97 6.2
# 98 5.1
# 99 5.7
# 100 6.3
# 101 5.8
# 102 7.1
# 103 6.3
# 104 6.5
# 105 7.6
# 106 4.9
# 107 7.3
# 108 6.7
# 109 7.2
# 110 6.5
# ...

# %%
for x in iris.itertuples():
    print(x)
# Out:
# Pandas(Index=0, sepal_length=5.1, sepal_width=3.5, petal_length=1.4, petal_width=0.2, species='setosa')
# Pandas(Index=1, sepal_length=4.9, sepal_width=3.0, petal_length=1.4, petal_width=0.2, species='setosa')
# Pandas(Index=2, sepal_length=4.7, sepal_width=3.2, petal_length=1.3, petal_width=0.2, species='setosa')
# Pandas(Index=3, sepal_length=4.6, sepal_width=3.1, petal_length=1.5, petal_width=0.2, species='setosa')
# Pandas(Index=4, sepal_length=5.0, sepal_width=3.6, petal_length=1.4, petal_width=0.2, species='setosa')
# Pandas(Index=5, sepal_length=5.4, sepal_width=3.9, petal_length=1.7, petal_width=0.4, species='setosa')
# Pandas(Index=6, sepal_length=4.6, sepal_width=3.4, petal_length=1.4, petal_width=0.3, species='setosa')
# Pandas(Index=7, sepal_length=5.0, sepal_width=3.4, petal_length=1.5, petal_width=0.2, species='setosa')
# Pandas(Index=8, sepal_length=4.4, sepal_width=2.9, petal_length=1.4, petal_width=0.2, species='setosa')
# ...
