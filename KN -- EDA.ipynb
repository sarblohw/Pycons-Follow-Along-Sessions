# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
train = pd.read_csv("C:/Users/singh/OneDrive/Documents/active_directory/EDA1-master/titanic_train.csv")

# %%
train.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
train.shape
# Out:
# (891, 12)

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(train.isna(), yticklabels = False, cmap = 'viridis', cbar = False, )
# Out:
# <AxesSubplot:>

# %%
sns.set_style('dark')
sns.countplot(x = 'Survived', data = train)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x = 'Survived', data = train)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
plt.style.use('ggplot')

# %%
sns.countplot(x = 'Survived', data = train)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.displot(train.Fare, bins=15)

# %%
import altair as alt

# %%
alt.Chart(train).mark_bar().encode(
    x = 'count(Sex)',
    y = 'Sex'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(train).mark_bar().encode(
    x = 'count(Survived)',
    y = 'Sex'
)
# Out:
# alt.Chart(...)

# %%
train.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
sns.countplot(y = 'Survived', data = train)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Survived'>

# %%
sns.countplot(data=train, x='Survived', hue='Sex', palette='Set3')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.catplot(data=train, x='Pclass', hue='Sex', col='Survived', kind='count', palette='Set3')

# %%
sns.countplot(data=train, x='Survived', hue='Pclass', palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.displot(data=train.Age, bins=40, color='tomato')

# %%
sns.displot(data=train.Age, bins=40, color='tomato', kde=True)

# %%
train.Age.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
train.Age.dropna().plot(kind='hist', bins=25, color='c', alpha=0.3)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
train['Age'].dropna().hist(bins=30, color='c', alpha=0.3)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='SibSp', data=train)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
sns.boxplot(x='Age', data=train)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(x='SibSp', y='Age', data=train)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Age'>

# %%
sns.boxplot(x='Pclass', y='Age', data=train, palette='winter')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(x='Pclass', y='Age', data=train, palette='Set3')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(x='Pclass', y='Age', data=train, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
train.shape
# Out:
# (891, 12)

# %%
train.loc[train.Age.isna(), 'Pclass'].apply(
    lambda x: 37 if x==1 else 29 if x==2 else 24, axis=1)
# Out:
# Series([], Name: Pclass, dtype: int64)

# %%
train.loc[train.Age.isna(), 'Pclass'].shape
# Out:
# (177,)

# %%
train.Age.isna().sum()
# Out:
# 177

# %%
train.loc[train.Age.isna(), 'Age'] = train.loc[train.Age.isna(), 'Pclass'].apply(
    lambda x: 37 if x==1 else 29 if x==2 else 24)

# %%
train.Age.isna().sum()
# Out:
# 0

# %%
pd.isna(train.Age).value_counts()
# Out:
# False    891
# Name: Age, dtype: int64

# %%
sns.heatmap(train.isna(), yticklabels=False, cmap='viridis', cbar=False)
# Out:
# <AxesSubplot:>

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.drop(columns='Cabin', inplace=True)

# %%
sns.heatmap(train.isna(), yticklabels=False, cmap='viridis', cbar=False)
# Out:
# <AxesSubplot:>

# %%
train.dropna(axis=0, how='any', subset=['Embarked'], inplace=True)

# %%
sns.heatmap(train.isna(), yticklabels=False, cmap='viridis', cbar=False)
# Out:
# <AxesSubplot:>

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
train.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S

# %%
train.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
pd.get_dummies(train.Embarked, drop_first=True)
# Out:
#      Q  S
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 886  0  1
# 887  0  1
# 888  0  1
# 889  0  0
# 890  1  0
#
# [889 rows x 2 columns]

# %%
embarked = pd.get_dummies(train.Embarked, drop_first=True)

# %%
pd.get_dummies(train.Sex, drop_first=True)
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 886     1
# 887     0
# 888     0
# 889     1
# 890     1
#
# [889 rows x 1 columns]

# %%
sex = pd.get_dummies(train.Sex, drop_first=True)

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
train.drop(columns=['Name', 'Sex', 'Embarked', 'Ticket'], inplace=True)

# %%
train.head(3)
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250

# %%
train.shape
# Out:
# (889, 7)

# %%
pd.concat([train, sex, embarked], axis=1, join='outer').shape
# Out:
# (889, 10)

# %%
df = pd.concat([train, sex, embarked], axis=1, join='outer')

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0            1         0       3  22.0      1      0   7.2500     1  0  1
# 1            2         1       1  38.0      1      0  71.2833     0  0  0
# 2            3         1       3  26.0      0      0   7.9250     0  0  1

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(columns='Survived')

# %%
y = df.Survived

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.30, random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_model = LogisticRegression()

# %%
logistic_model.fit(X_train, y_train)
# Out:
# C:\Users\singh\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions = logistic_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
accuracy = confusion_matrix(y_test, predictions)

# %%
accuracy
# Out:
# array([[149,  14],
#        [ 39,  65]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
acc_score = accuracy_score(y_test, predictions)

# %%
acc_score
# Out:
# 0.8014981273408239
