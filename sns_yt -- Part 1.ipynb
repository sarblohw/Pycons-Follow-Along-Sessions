# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
car_crashes = sns.load_dataset('car_crashes')

# %%
car_crashes.head(3)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ

# %% [markdown]
# ### Distribution Plot
# + Univariate Plots
# + Histogram or frequency distribution and KDE/Kernel Density Estimate plot
# + Histogram dicretesizes a continuous variable by using bins (also called intervals, classes, buckets)
# + KDE plots depict density distribution of Kernels using a line, does not discretesize the continuous variable
# + A combination of the 2 plots helps plot a distribution plot using sns

# %%
sns.distplot(car_crashes.not_distracted)
# Out:
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='not_distracted', ylabel='Density'>

# %%
sns.distplot(car_crashes.not_distracted, kde=False)
# Out:
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='not_distracted'>

# %%
sns.distplot(car_crashes.not_distracted, bins=25)
#decreasing bins can reduce information while increasing too much can cause noise in the data
# Out:
# <AxesSubplot:xlabel='not_distracted', ylabel='Density'>

# %%
sns.distplot(car_crashes.not_distracted, hist=False)
# Out:
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='not_distracted', ylabel='Density'>

# %% [markdown]
# ## Joint Plot
# + Plots distribution between 2 variables - Bivariate
# + Plots scatter plot by default and shows 2 distribution plots for each variable

# %%
sns.jointplot(x='speeding', y='alcohol', data=car_crashes, kind='kde', fill=True)

# %%
sns.jointplot(x='speeding', y='alcohol', data=car_crashes)

# %%
sns.jointplot(x='speeding', y='alcohol', data=car_crashes, kind='reg')

# %%
sns.heatmap(car_crashes.corr())
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='speeding', y='alcohol', data=car_crashes, kind='hex')

# %%
sns.kdeplot(car_crashes.speeding, fill=True)
# Out:
# <AxesSubplot:xlabel='speeding', ylabel='Density'>

# %%
sns.kdeplot(car_crashes.alcohol)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# ## Pair Plot
# + Plots all numerical variables in the dataset and shows their relations

# %%
sns.pairplot(car_crashes)

# %%
tips = sns.load_dataset('tips')

# %%
sns.pairplot(tips, hue='sex', palette='Blues')

# %%
#Rug Plot
sns.rugplot(tips.tip)
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.set_style('white')
sns.jointplot(x='speeding', y='alcohol', data=car_crashes, kind='reg')

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,8), dpi=140)
sns.jointplot(x='speeding', y='alcohol', data=car_crashes, kind='reg')

# %%
sns.set_style('ticks')
sns.jointplot(x='speeding', y='alcohol', data=car_crashes, kind='reg')

# %%
sns.set_style('whitegrid')
sns.jointplot(x='speeding', y='alcohol', data=car_crashes, kind='reg')

# %%
sns.set_style('dark')
sns.jointplot(x='speeding', y='alcohol', data=car_crashes, kind='reg')

# %%
sns.set_style('ticks')
sns.jointplot(x='speeding', y='alcohol', data=car_crashes, kind='reg')

# %%
sns.set_style('darkgrid')
sns.set_context('paper', font_scale=1.4)
sns.jointplot(x='speeding', y='alcohol', data=car_crashes, kind='reg')

# %%
sns.set_style('whitegrid')
sns.set_context('talk', font_scale=1.4)
sns.jointplot(x='speeding', y='alcohol', data=car_crashes, kind='reg')

# %%
sns.set_style('darkgrid')
sns.set_context('poster', font_scale=1.4)
sns.jointplot(x='speeding', y='alcohol', data=car_crashes, kind='reg')
# Out:
# C:\Users\singh\anaconda3\lib\site-packages\seaborn\axisgrid.py:1668: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   f.tight_layout()

# %%
sns.set_style('ticks')
sns.set_context('paper', font_scale=1.5)
sns.jointplot(x='speeding', y='alcohol', data=car_crashes, kind='reg')
sns.despine(left=True, bottom=False)

# %%
sns.set_style('ticks')
sns.set_context('paper', font_scale=1.5)
sns.jointplot(x='speeding', y='alcohol', data=car_crashes, kind='reg')
sns.despine(left=True, bottom=True)

# %%
sns.set_style('whitegrid')
sns.jointplot(x='speeding', y='alcohol', data=car_crashes, kind='kde', fill=True)
sns.set_context('paper', font_scale=1.2)
sns.despine(left=True, bottom=True)

# %%
sns.set_style('ticks')
sns.set_context('paper', font_scale=1.5)
sns.jointplot(x='speeding', y='alcohol', data=car_crashes, kind='scatter')
sns.despine(left=True, bottom=False)

# %% [markdown]
# # Categorical Plots
#
# ## Barplots

# %%
sns.barplot(x='sex', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>
