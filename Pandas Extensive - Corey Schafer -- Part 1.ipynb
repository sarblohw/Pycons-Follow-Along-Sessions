# %%
# iterating through the rows of a df - YT short video

# %%
import pandas as pd

# %%
iris = pd.read_csv('Iris.csv', index_col = 'Id')

# %%
iris.head(10)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa
# 6             5.4           3.9            1.7           0.4  Iris-setosa
# 7             4.6           3.4            1.4           0.3  Iris-setosa
# 8             5.0           3.4            1.5           0.2  Iris-setosa
# 9             4.4           2.9            1.4           0.2  Iris-setosa
# 10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
[x for x in iris['SepalWidthCm']]
# Out:
# [3.5,
#  3.0,
#  3.2,
#  3.1,
#  3.6,
#  3.9,
#  3.4,
#  3.4,
#  2.9,
#  3.1,
#  3.7,
#  3.4,
#  3.0,
#  3.0,
#  4.0,
#  4.4,
#  3.9,
#  3.5,
#  3.8,
#  3.8,
#  3.4,
#  3.7,
#  3.6,
#  3.3,
#  3.4,
#  3.0,
#  3.4,
#  3.5,
#  3.4,
#  3.2,
#  3.1,
#  3.4,
#  4.1,
#  4.2,
#  3.1,
#  3.2,
#  3.5,
#  3.1,
#  3.0,
#  3.4,
#  3.5,
#  2.3,
#  3.2,
#  3.5,
#  3.8,
#  3.0,
#  3.8,
#  3.2,
#  3.7,
#  3.3,
#  3.2,
#  3.2,
#  3.1,
#  2.3,
#  2.8,
#  2.8,
#  3.3,
#  2.4,
#  2.9,
#  2.7,
#  2.0,
#  3.0,
#  2.2,
#  2.9,
#  2.9,
#  3.1,
#  3.0,
#  2.7,
#  2.2,
#  2.5,
#  3.2,
#  2.8,
#  2.5,
#  2.8,
#  2.9,
#  3.0,
#  2.8,
#  3.0,
#  2.9,
#  2.6,
#  2.4,
#  2.4,
#  2.7,
#  2.7,
#  3.0,
#  3.4,
#  3.1,
#  2.3,
#  3.0,
#  2.5,
#  2.6,
#  3.0,
#  2.6,
#  2.3,
#  2.7,
#  3.0,
#  2.9,
#  2.9,
#  2.5,
#  2.8,
#  3.3,
#  2.7,
#  3.0,
#  2.9,
#  3.0,
#  3.0,
#  2.5,
#  2.9,
#  2.5,
#  3.6,
#  3.2,
#  2.7,
#  3.0,
#  2.5,
#  2.8,
#  3.2,
#  3.0,
#  3.8,
#  2.6,
#  2.2,
#  3.2,
#  2.8,
#  2.8,
#  2.7,
#  3.3,
# ...

# %%
for i,row in iris.iterrows():
  print (i, row['SepalLengthCm'])
# Out:
# 1 5.1
# 2 4.9
# 3 4.7
# 4 4.6
# 5 5.0
# 6 5.4
# 7 4.6
# 8 5.0
# 9 4.4
# 10 4.9
# 11 5.4
# 12 4.8
# 13 4.8
# 14 4.3
# 15 5.8
# 16 5.7
# 17 5.4
# 18 5.1
# 19 5.7
# 20 5.1
# 21 5.4
# 22 5.1
# 23 4.6
# 24 5.1
# 25 4.8
# 26 5.0
# 27 5.0
# 28 5.2
# 29 5.2
# 30 4.7
# 31 4.8
# 32 5.4
# 33 5.2
# 34 5.5
# 35 4.9
# 36 5.0
# 37 5.5
# 38 4.9
# 39 4.4
# 40 5.1
# 41 5.0
# 42 4.5
# 43 4.4
# 44 5.0
# 45 5.1
# 46 4.8
# 47 5.1
# 48 4.6
# 49 5.3
# 50 5.0
# 51 7.0
# 52 6.4
# 53 6.9
# 54 5.5
# 55 6.5
# 56 5.7
# 57 6.3
# 58 4.9
# 59 6.6
# 60 5.2
# 61 5.0
# 62 5.9
# 63 6.0
# 64 6.1
# 65 5.6
# 66 6.7
# 67 5.6
# 68 5.8
# 69 6.2
# 70 5.6
# 71 5.9
# 72 6.1
# 73 6.3
# 74 6.1
# 75 6.4
# 76 6.6
# 77 6.8
# 78 6.7
# 79 6.0
# 80 5.7
# 81 5.5
# 82 5.5
# 83 5.8
# 84 6.0
# 85 5.4
# 86 6.0
# 87 6.7
# 88 6.3
# 89 5.6
# 90 5.5
# 91 5.5
# 92 6.1
# 93 5.8
# 94 5.0
# 95 5.6
# 96 5.7
# 97 5.7
# 98 6.2
# 99 5.1
# 100 5.7
# 101 6.3
# 102 5.8
# 103 7.1
# 104 6.3
# 105 6.5
# 106 7.6
# 107 4.9
# 108 7.3
# 109 6.7
# 110 7.2
# ...

# %%
for rows in iris.itertuples():
    print(rows)
# Out:
# Pandas(Index=1, SepalLengthCm=5.1, SepalWidthCm=3.5, PetalLengthCm=1.4, PetalWidthCm=0.2, Species='Iris-setosa')
# Pandas(Index=2, SepalLengthCm=4.9, SepalWidthCm=3.0, PetalLengthCm=1.4, PetalWidthCm=0.2, Species='Iris-setosa')
# Pandas(Index=3, SepalLengthCm=4.7, SepalWidthCm=3.2, PetalLengthCm=1.3, PetalWidthCm=0.2, Species='Iris-setosa')
# Pandas(Index=4, SepalLengthCm=4.6, SepalWidthCm=3.1, PetalLengthCm=1.5, PetalWidthCm=0.2, Species='Iris-setosa')
# Pandas(Index=5, SepalLengthCm=5.0, SepalWidthCm=3.6, PetalLengthCm=1.4, PetalWidthCm=0.2, Species='Iris-setosa')
# Pandas(Index=6, SepalLengthCm=5.4, SepalWidthCm=3.9, PetalLengthCm=1.7, PetalWidthCm=0.4, Species='Iris-setosa')
# Pandas(Index=7, SepalLengthCm=4.6, SepalWidthCm=3.4, PetalLengthCm=1.4, PetalWidthCm=0.3, Species='Iris-setosa')
# Pandas(Index=8, SepalLengthCm=5.0, SepalWidthCm=3.4, PetalLengthCm=1.5, PetalWidthCm=0.2, Species='Iris-setosa')
# ...

# %%
# corey schafer pandas series

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df.head(5)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.isnull().sum()
# Out:
# Respondent          0
# MainBranch        552
# Hobbyist            0
# OpenSourcer         0
# OpenSource       2041
#                 ...
# Sexuality       12736
# Ethnicity       12215
# Dependents       5824
# SurveyLength     1899
# SurveyEase       1802
# Length: 85, dtype: int64

# %%
# both commands do the same thing

pd.options.display.max_columns = 85
pd.set_option('display.max_columns', 85)

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
pd.set_option('display.max_rows', 85)

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %% [markdown]
# ---
#
#
# **In basic python either nested lists or lists in a dictionary can be somewhat compared to a dataframe...**
#
#
# ---
#
#
#
# ---

# %%
person = {
    'fname' : 'Suminder',
    'lname' : 'Singh',
    'email' : 'suminder.singh@ex.com'
}

# %%
people = {
    'fname' : ['Suminder'],
    'lname' : ['Singh'],
    'email' : ['suminder.singh@ex.com']
}

# %%
multiple_people = {
    'fname' : ['Suminder', 'Deepinder', 'Nimrat'],
    'lname' : ['Singh', 'Kaur', 'Kaur'],
    'email' : ['suminder.singh@ex.com', 'dkaur@ex.com', 'nkaur@ex.com']
}

# %%
df_multiple_ppl = pd.DataFrame(multiple_people)

# %%
df_multiple_ppl
# Out:
#        fname  lname                  email
# 0   Suminder  Singh  suminder.singh@ex.com
# 1  Deepinder   Kaur           dkaur@ex.com
# 2     Nimrat   Kaur           nkaur@ex.com

# %%
multiple_people['email']
# Out:
# ['suminder.singh@ex.com', 'dkaur@ex.com', 'nkaur@ex.com']

# %%
df_multiple_ppl['email'] # dtype -> panda series
# Out:
# 0    suminder.singh@ex.com
# 1             dkaur@ex.com
# 2             nkaur@ex.com
# Name: email, dtype: object

# %%
df_multiple_ppl[['lname', 'email']] # dtype -> panda dataframe
# Out:
#    lname                  email
# 0  Singh  suminder.singh@ex.com
# 1   Kaur           dkaur@ex.com
# 2   Kaur           nkaur@ex.com

# %%
df_multiple_ppl.email # dot notation
# Out:
# 0    suminder.singh@ex.com
# 1             dkaur@ex.com
# 2             nkaur@ex.com
# Name: email, dtype: object

# %%
df_multiple_ppl.columns
# Out:
# Index(['fname', 'lname', 'email'], dtype='object')

# %%
df_multiple_ppl.iloc[0]
# Out:
# fname                 Suminder
# lname                    Singh
# email    suminder.singh@ex.com
# Name: 0, dtype: object

# %%
df_multiple_ppl.iloc[[0,1]]
# Out:
#        fname  lname                  email
# 0   Suminder  Singh  suminder.singh@ex.com
# 1  Deepinder   Kaur           dkaur@ex.com

# %%
df_multiple_ppl.iloc[[0,1], 2]
# Out:
# 0    suminder.singh@ex.com
# 1             dkaur@ex.com
# Name: email, dtype: object

# %%
df_multiple_ppl.iloc[[0,1], [1,2]]
# Out:
#    lname                  email
# 0  Singh  suminder.singh@ex.com
# 1   Kaur           dkaur@ex.com

# %%
df_multiple_ppl.loc[0]
# loc will use index and column names as arguements... here the index is numerals 0 to n
# Out:
# fname                 Suminder
# lname                    Singh
# email    suminder.singh@ex.com
# Name: 0, dtype: object

# %%
df_multiple_ppl
# Out:
#        fname  lname                  email
# 0   Suminder  Singh  suminder.singh@ex.com
# 1  Deepinder   Kaur           dkaur@ex.com
# 2     Nimrat   Kaur           nkaur@ex.com

# %%
df_multiple_ppl.loc[[0,1], 'email']
# Out:
# 0    suminder.singh@ex.com
# 1             dkaur@ex.com
# Name: email, dtype: object

# %%
df_multiple_ppl.loc[[0,1], ['email', 'lname']]
# Out:
#                    email  lname
# 0  suminder.singh@ex.com  Singh
# 1           dkaur@ex.com   Kaur

# %%
df = pd.read_csv('survey_results_public.csv')
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df.Hobbyist
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[[0, 1, 2], 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[0:3, 'Hobbyist'] # end index is inclusive here
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# Name: Hobbyist, dtype: object

# %%
df.loc[0:2, 'Hobbyist':'Employment']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %% [markdown]
# #### Part 3 - Indexes and their operations in a DF

# %%
multiple_people = {
    'fname' : ['Suminder', 'Deepinder', 'Nimrat'],
    'lname' : ['Singh', 'Kaur', 'Kaur'],
    'email' : ['suminder.singh@ex.com', 'dkaur@ex.com', 'nkaur@ex.com']
}

df_tst = pd.DataFrame(multiple_people)

# %%
df_tst
# Out:
#        fname  lname                  email
# 0   Suminder  Singh  suminder.singh@ex.com
# 1  Deepinder   Kaur           dkaur@ex.com
# 2     Nimrat   Kaur           nkaur@ex.com

# %%
df_tst['email']
# Out:
# 0    suminder.singh@ex.com
# 1             dkaur@ex.com
# 2             nkaur@ex.com
# Name: email, dtype: object

# %%
df_tst.set_index('email')
# Out:
#                            fname  lname
# email
# suminder.singh@ex.com   Suminder  Singh
# dkaur@ex.com           Deepinder   Kaur
# nkaur@ex.com              Nimrat   Kaur

# %%
df_tst
# Out:
#        fname  lname                  email
# 0   Suminder  Singh  suminder.singh@ex.com
# 1  Deepinder   Kaur           dkaur@ex.com
# 2     Nimrat   Kaur           nkaur@ex.com

# %%
df_tst.set_index('email', inplace = True)

# %%
df_tst.index
# Out:
# Index(['suminder.singh@ex.com', 'dkaur@ex.com', 'nkaur@ex.com'], dtype='object', name='email')

# %%
df_tst.loc['suminder.singh@ex.com']
# Out:
# fname    Suminder
# lname       Singh
# Name: suminder.singh@ex.com, dtype: object

# %%
df_tst.loc['suminder.singh@ex.com', 'lname']
# Out:
# 'Singh'

# %%
df_tst.reset_index(inplace = True)

# %%
df_tst
# Out:
#                    email      fname  lname
# 0  suminder.singh@ex.com   Suminder  Singh
# 1           dkaur@ex.com  Deepinder   Kaur
# 2           nkaur@ex.com     Nimrat   Kaur

# %%
df = pd.read_csv('survey_results_public.csv', index_col = 'Respondent')

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.loc[1]
# Out:
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# DevType                                                                 NaN
# ...

# %%
schema_df.head()
# Out:
#         Column                                       QuestionText
# 0   Respondent  Randomized respondent ID number (not in order ...
# 1   MainBranch  Which of the following options best describes ...
# 2     Hobbyist                            Do you code as a hobby?
# 3  OpenSourcer        How often do you contribute to open source?
# 4   OpenSource  How do you feel about the quality of open sour...

# %%
schema_df.set_index('Column', inplace=True)

# %%
schema_df.head()
# Out:
#                                                   QuestionText
# Column
# Respondent   Randomized respondent ID number (not in order ...
# MainBranch   Which of the following options best describes ...
# Hobbyist                               Do you code as a hobby?
# OpenSourcer        How often do you contribute to open source?
# OpenSource   How do you feel about the quality of open sour...

# %%
schema_df.sort_index().head()
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...

# %%
schema_df.loc['MgrIdiot'] # notice diff in output in this and the nxt cell
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %%
schema_df.loc['MgrIdiot', 'QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df.sort_index(inplace=True, ascending=False)

# %%
schema_df.head()
# Out:
#                                                    QuestionText
# Column
# YearsCodePro  How many years have you coded professionally (...
# YearsCode     Including any education, how many years have y...
# WorkWeekHrs    On average, how many hours per week do you work?
# WorkRemote                      How often do you work remotely?
# WorkPlan                How structured or planned is your work?

# %% [markdown]
# #### Part 4 - Filtering

# %%
multiple_people = {
    'fname' : ['Suminder', 'Deepinder', 'Nimrat'],
    'lname' : ['Singh', 'Kaur', 'Kaur'],
    'email' : ['suminder.singh@ex.com', 'dkaur@ex.com', 'nkaur@ex.com']
}

df_tst = pd.DataFrame(multiple_people)

# %%
df_tst['lname'] == 'Singh' # filter mask
# Out:
# 0     True
# 1    False
# 2    False
# Name: lname, dtype: bool

# %%
filt = (df_tst['lname'] == 'Singh')
df_tst[filt]
# Out:
#       fname  lname                  email
# 0  Suminder  Singh  suminder.singh@ex.com

# %%
df_tst[df_tst['lname'] == 'Singh']
# Out:
#       fname  lname                  email
# 0  Suminder  Singh  suminder.singh@ex.com

# %%
df_tst.loc[filt]
# Out:
#       fname  lname                  email
# 0  Suminder  Singh  suminder.singh@ex.com

# %%
df_tst.loc[filt, 'email']
# Out:
# 0    suminder.singh@ex.com
# Name: email, dtype: object

# %%
# operators - &, |, &&

# %%
filt_2 = (df_tst['lname'] == 'Kaur') & (df_tst['fname'] == 'Nimrat')
df_tst.loc[filt_2, 'email']
# Out:
# 2    nkaur@ex.com
# Name: email, dtype: object

# %%
df_tst.loc[(df_tst['fname'] == 'Suminder') | (df_tst['fname'] == 'Nimrat'), 'email']
# Out:
# 0    suminder.singh@ex.com
# 2             nkaur@ex.com
# Name: email, dtype: object

# %%
df_tst.loc[~((df_tst['fname'] == 'Suminder') | (df_tst['fname'] == 'Nimrat')), 'email']
# tilde ~ can be used to reverse
# Out:
# 1    dkaur@ex.com
# Name: email, dtype: object

# %%
df = pd.read_csv('survey_results_public.csv')
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
high_salary = df['ConvertedComp'] > 70000

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#               Country                                 LanguageWorkedWith  \
# 5              Canada                                         Java;R;SQL
# 8         New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 12      United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 15     United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 21      United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...               ...                                                ...
# 88323   United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88324   United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88325   United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88326         Finland                   Bash/Shell/PowerShell;C++;Python
# 88329     Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
#        ConvertedComp
# 5           366420.0
# 8            95179.0
# 12           90000.0
# ...

# %%
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']

# %%
filt_country = df['Country'].isin(countries)
df.loc[filt_country, 'Country']
# Out:
# 0        United Kingdom
# 3         United States
# 5                Canada
# 7                 India
# 9                 India
#               ...
# 88859     United States
# 88863    United Kingdom
# 88864             India
# 88877     United States
# 88878            Canada
# Name: Country, Length: 45008, dtype: object

# %%
df.loc[df['LanguageWorkedWith'].str.contains('Python', na=False), 'LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %% [markdown]
# #### Part 5 - Updating Rows and Columns

# %%
multiple_people = {
    'fname' : ['Suminder', 'Deepinder', 'Nimrat'],
    'lname' : ['Singh', 'Kaur', 'Kaur'],
    'email' : ['suminder.singh@ex.com', 'dkaur@ex.com', 'nkaur@ex.com']
}

df_tst = pd.DataFrame(multiple_people)
